# %% [markdown]
# ##ML-Midterm- question4

# %% [markdown]
# ## .mat to csv

# %%
# https://drive.google.com/file/d/1o4OXgpSXJys-AywUHq-MKGMM-hUDSJ59/view?usp=sharing
# !gdown 1o4OXgpSXJys-AywUHq-MKGMM-hUDSJ59
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?id=1o4OXgpSXJys-AywUHq-MKGMM-hUDSJ59
# From (redirected): https://drive.google.com/uc?id=1o4OXgpSXJys-AywUHq-MKGMM-hUDSJ59&confirm=t&uuid=b496fe8e-3e01-4fc6-b5a2-23d2b57f2664
# To: /content/DATA.mat
# 100% 2.91M/2.91M [00:00<00:00, 137MB/s]

# %%
from scipy.io import loadmat
mat = loadmat('/content/DATA.mat')
print(mat)
# Out:
# {'__header__': b'MATLAB 5.0 MAT-file, Platform: PCWIN64, Created on: Fri Jun 26 12:48:29 2020', '__version__': '1.0', '__globals__': [], 'NOV17': array([[0.0000e+00, 6.4200e+02, 3.5900e+02, ..., 1.4010e+02, 1.7200e+02,
#         1.3360e+02],
#        [1.0000e+00, 6.3590e+02, 3.5680e+02, ..., 1.4010e+02, 1.7200e+02,
#         1.3360e+02],
#        [2.0000e+00, 6.3880e+02, 3.5600e+02, ..., 1.4010e+02, 1.7200e+02,
#         1.3360e+02],
#        ...,
#        [8.6397e+04, 6.6420e+02, 3.7260e+02, ..., 1.4040e+02, 1.7310e+02,
#         1.3370e+02],
#        [8.6398e+04, 6.7030e+02, 3.6290e+02, ..., 1.4040e+02, 1.7300e+02,
#         1.3370e+02],
#        [8.6399e+04, 6.6590e+02, 3.6310e+02, ..., 1.4040e+02, 1.7310e+02,
#         1.3380e+02]]), 'NOV9': array([[0.0000e+00, 6.9910e+02, 3.0060e+02, ..., 1.3690e+02, 1.6400e+02,
#         1.3210e+02],
#        [1.0000e+00, 6.9770e+02, 2.9890e+02, ..., 1.3690e+02, 1.6410e+02,
#         1.3210e+02],
# ...

# %%
print(mat.keys())
# Out:
# dict_keys(['__header__', '__version__', '__globals__', 'NOV17', 'NOV9'])

# %%
import pandas as pd
x = mat["NOV17"]
y = mat["NOV9"]
df = pd.DataFrame(x)
df1 = pd.DataFrame(y)
df.to_csv('example.csv', index = False)
df1.to_csv('example1.csv', index = False)

# %% [markdown]
# ## Data

# %%
# https://drive.google.com/file/d/1RjqfIn9HR9sm9ICp_8lkePrBHcAVabHr/view?usp=sharing
# !gdown 1RjqfIn9HR9sm9ICp_8lkePrBHcAVabHr
# https://drive.google.com/file/d/1OWFGitXKllOY6ala8-adogADIdMzlyYT/view?usp=sharing
# !gdown 1OWFGitXKllOY6ala8-adogADIdMzlyYT
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1RjqfIn9HR9sm9ICp_8lkePrBHcAVabHr
# To: /content/NOV9.csv
# 100% 7.92M/7.92M [00:00<00:00, 147MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1OWFGitXKllOY6ala8-adogADIdMzlyYT
# To: /content/NOV17.csv
# 100% 7.92M/7.92M [00:00<00:00, 45.0MB/s]

# %%
import pandas as pd
df = pd.read_csv("/content/NOV17.csv")
df
# Out:
#            0  699.1  300.6  97.8  296.2  42.7    42  46.1  129.1  133.4  12.2  \
# 0          1  697.7  298.9  97.8  295.4  41.8  41.6  45.3  129.1  133.3  12.2
# 1          2  696.2  301.8  97.8  295.4  42.9  41.4  46.6  129.1  133.4  12.2
# 2          3  702.8  300.9  97.7  295.1  43.1  41.5  46.0  129.1  133.4  12.2
# 3          4  701.3  292.6  97.8  294.6  42.6  42.3  47.0  129.1  133.4  12.2
# 4          5  701.1  298.4  97.8  293.4  43.5  42.3  46.7  129.1  133.4  12.2
# ...      ...    ...    ...   ...    ...   ...   ...   ...    ...    ...   ...
# 86394  86395  598.8  373.1  97.0  379.9  31.4  30.0  46.9  128.7  132.3  13.5
# 86395  86396  601.5  365.6  97.0  378.9  30.7  30.7  46.4  128.7  132.3  13.5
# 86396  86397  597.8  374.8  97.0  378.5  30.1  30.5  46.4  128.7  132.3  13.5
# 86397  86398  593.7  379.7  97.0  378.8  30.3  30.3  46.1  128.7  132.3  13.5
# 86398  86399  582.7  377.8  97.0  380.3  29.8  30.5  46.2  128.7  132.3  13.5
#
# ...

# %%
df1 = pd.read_csv("/content/NOV9.csv")
df1
# Out:
#            0  699.1  300.6  97.8  296.2  42.7    42  46.1  129.1  133.4  12.2  \
# 0          1  697.7  298.9  97.8  295.4  41.8  41.6  45.3  129.1  133.3  12.2
# 1          2  696.2  301.8  97.8  295.4  42.9  41.4  46.6  129.1  133.4  12.2
# 2          3  702.8  300.9  97.7  295.1  43.1  41.5  46.0  129.1  133.4  12.2
# 3          4  701.3  292.6  97.8  294.6  42.6  42.3  47.0  129.1  133.4  12.2
# 4          5  701.1  298.4  97.8  293.4  43.5  42.3  46.7  129.1  133.4  12.2
# ...      ...    ...    ...   ...    ...   ...   ...   ...    ...    ...   ...
# 86394  86395  598.8  373.1  97.0  379.9  31.4  30.0  46.9  128.7  132.3  13.5
# 86395  86396  601.5  365.6  97.0  378.9  30.7  30.7  46.4  128.7  132.3  13.5
# 86396  86397  597.8  374.8  97.0  378.5  30.1  30.5  46.4  128.7  132.3  13.5
# 86397  86398  593.7  379.7  97.0  378.8  30.3  30.3  46.1  128.7  132.3  13.5
# 86398  86399  582.7  377.8  97.0  380.3  29.8  30.5  46.2  128.7  132.3  13.5
#
# ...

# %%
Normal = pd.read_csv('/content/NOV9.csv')

null1 = Normal.isnull().sum()
print(null1)

Fault1 = pd.read_csv('/content/NOV17.csv')
null2 = Fault1.isnull().sum()
print(null2)
# Out:
# 0        0
# 699.1    0
# 300.6    0
# 97.8     0
# 296.2    0
# 42.7     0
# 42       0
# 46.1     0
# 129.1    0
# 133.4    0
# 12.2     0
# 26.4     0
# 53       0
# 242      0
# 136.9    0
# 164      0
# 132.1    0
# dtype: int64
# 0        0
# 699.1    0
# 300.6    0
# 97.8     0
# 296.2    0
# 42.7     0
# 42       0
# 46.1     0
# 129.1    0
# 133.4    0
# 12.2     0
# 26.4     0
# 53       0
# 242      0
# 136.9    0
# 164      0
# 132.1    0
# dtype: int64

# %% [markdown]
# ## fault

# %%
Normal_9Nov = pd.read_csv('/content/NOV9.csv')

f1_18 = Normal_9Nov[58800: 59800]
f1_16 = Normal_9Nov[57275: 57550]
f2_18 = Normal_9Nov[58829: 58929]
f3_18 = Normal_9Nov[58520: 58625]

#برای 17 ام
f4_18 = Normal_9Nov[54600: 54700]
f2_16 = Normal_9Nov[54670: 54770]

# %%
import pandas as pd
import numpy as np
from imblearn.under_sampling import RandomUnderSampler
Normal_9Nov = pd.read_csv('/content/NOV9.csv')
df = Normal_9Nov
df = df.drop(df.columns[0], axis=1)

f1_16 = Normal_9Nov[57275: 57550]
f2_18 = Normal_9Nov[58829: 58929]
f3_18 = Normal_9Nov[58520: 58625]

# Define the index ranges and corresponding labels
label_ranges = [(57274, 57549, 0), (58829, 58929, 1), (58519, 58624,1 )]

# Initialize a new column for labels with default values (NaN)
df['Label'] = pd.NA

# Apply labels based on the defined ranges
for start, end, label in label_ranges:
    df.loc[start:end, 'Label'] = label

# Filter only labeled data
labeled_df = df.dropna(subset=['Label'])

# Split data into features (X) and labels (y)
X = labeled_df.drop('Label', axis=1)
y = labeled_df['Label'].astype(int)  # Ensure y is of integer type

# Count the number of samples in each class before balancing
unique, counts = np.unique(y, return_counts=True)
print("Class counts before balancing:", dict(zip(unique, counts)))

# Use RandomUnderSampler to balance the classes
rus = RandomUnderSampler(random_state=64)
X_resampled, y_resampled = rus.fit_resample(X, y)

# Count the number of samples in each class after balancing
unique_resampled, counts_resampled = np.unique(y_resampled, return_counts=True)
print("Class counts after balancing:", dict(zip(unique_resampled, counts_resampled)))

# Print the shape of the new balanced dataset
print("\nNew balanced dataset shape:", X_resampled.shape, y_resampled.shape)
# Out:
# Class counts before balancing: {0: 276, 1: 207}
# Class counts after balancing: {0: 207, 1: 207}
#
# New balanced dataset shape: (414, 16) (414,)

# %%
data_matrix =(X_resampled, y_resampled)
data_matrix
# Out:
# (     699.1  300.6  97.8  296.2   42.7    42  46.1  129.1  133.4  12.2  26.4  \
#  0    496.0  417.6  96.8  427.0   99.8   3.9  81.0  127.3  134.1  13.3  20.2
#  1    603.7  381.7  96.8  394.0  100.0  29.6  93.8  126.8  134.3  13.3  19.9
#  2    613.7  372.9  96.8  389.5  100.0  30.4  94.5  126.8  134.3  13.3  19.8
#  3    614.7  381.4  96.8  384.6   36.7  30.9  47.9  127.8  131.9  13.2  21.0
#  4    506.0  416.1  96.8  424.8  100.0  12.9  77.2  127.4  134.0  13.2  20.0
#  ..     ...    ...   ...    ...    ...   ...   ...    ...    ...   ...   ...
#  409  720.6  307.4  96.3  312.3   69.9  65.4  63.9  128.2  134.0  13.5  19.8
#  410  739.2  291.3  96.3  295.0   70.2  64.4  63.9  128.2  134.0  13.5  19.7
#  411  753.6  269.8  96.3  283.6   69.6  64.1  63.4  128.2  134.0  13.5  19.6
#  412  776.8  251.8  96.3  270.6   69.4  62.7  62.6  128.2  134.0  13.5  19.6
#  413  792.7  245.4  96.3  252.9   68.3  63.0  62.0  128.2  134.0  13.5  19.6
#
#         53    242  136.9    164  132.1
# ...

# %% [markdown]
# #Feature extraction

# %%
mean_values = np.mean(data_matrix, axis=1)
std_dev_values = np.std(data_matrix, axis=1)
peak_values = np.max(np.abs(data_matrix), axis=1)
rms_value = np.sqrt(np.mean(data_matrix**2, axis=1))
crest_factor = peak_values / rms_value
peak_to_peak_value=np.max(data_matrix, axis=1)-np.min(data_matrix, axis=1)
Abs_Mean_value=np.mean(np.abs(data_matrix), axis=1)
Impulse_Factor=peak_values/Abs_Mean_value
# Concatenate mean and standard deviation as features
features = np.column_stack((mean_values, std_dev_values, peak_values, rms_value, crest_factor, peak_to_peak_value, Abs_Mean_value, Impulse_Factor))
# Create DataFrame
Data = pd.DataFrame(features)
print(Data)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-124-f2cc3a381279> in <cell line: 1>()
# ----> 1 mean_values = np.mean(data_matrix, axis=1)
#       2 std_dev_values = np.std(data_matrix, axis=1)
#       3 peak_values = np.max(np.abs(data_matrix), axis=1)
#       4 rms_value = np.sqrt(np.mean(data_matrix**2, axis=1))
#       5 crest_factor = peak_values / rms_value
#
# /usr/local/lib/python3.10/dist-packages/numpy/core/fromnumeric.py in mean(a, axis, dtype, out, keepdims, where)
#    3502             return mean(axis=axis, dtype=dtype, out=out, **kwargs)
#    3503
# -> 3504     return _methods._mean(a, axis=axis, dtype=dtype,
#    3505                           out=out, **kwargs)
#    3506
#
# /usr/local/lib/python3.10/dist-packages/numpy/core/_methods.py in _mean(a, axis, dtype, out, keepdims, where)
#     100
# ...

# %%
import numpy as np
data = data_matrix
# For each feature we used the given formula
#1. Peak
def calculate_peak(data):
    return np.max(data)

#2.crest_factor
def calculate_crest_factor(data):
    peak = calculate_peak(data)
    rms = np.sqrt(np.mean(np.square(data)))
    return peak / rms

#3.clearance_factor
def calculate_clearance_factor(data):
    peak = calculate_peak(data)
    return peak / (np.max(np.abs(data)))
#4.shape_factor
def calculate_shape_factor(data):
    rms = np.sqrt(np.mean(np.square(data)))
    mean = np.mean(data)
    return rms / mean

#5.mean
def calculate_mean(data):
    return np.mean(data)

#6. absolute_mean
def calculate_absolute_mean(data):
    return np.mean(np.abs(data))

#7.peak_to_peak
def calculate_peak_to_peak(data):
    return np.max(data) - np.min(data)

#8.impact_factor
def calculate_impact_factor(data):
    return np.max(np.abs(data))
calculate_peak(data)
# n = 100
# # A : Normal
# Normal_features = []
# for i in range(n):
#     features = []
#     data = X_resampled[:, i]
#     features.append(calculate_peak(data))
#     features.append(calculate_crest_factor(data))
#     features.append(calculate_clearance_factor(data))
#     features.append(calculate_absolute_mean(data))
#     features.append(calculate_mean(data))
#     features.append(calculate_shape_factor(data))
#     features.append(calculate_peak_to_peak(data))
#     features.append(calculate_impact_factor(data))
#     Normal_features.append(features)

# # B : fault
# Fault_features = []
# for i in range(n):
#     features = []
#     data = y_resampled[:, i]
#     features.append(calculate_peak(data))
#     features.append(calculate_crest_factor(data))
#     features.append(calculate_clearance_factor(data))
#     features.append(calculate_absolute_mean(data))
#     features.append(calculate_mean(data))
#     features.append(calculate_shape_factor(data))
#     features.append(calculate_peak_to_peak(data))
#     features.append(calculate_impact_factor(data))
#     Fault_features.append(features)

# Normal_features = np.array(Normal_features)
# fault_features = np.array(Fault_features)

# print("Normal Data features:")
# print(Normal_features)

# print("Fault Data features:")
# print(fault_features)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-107-dcf249a6ee1d> in <cell line: 39>()
#      37 def calculate_impact_factor(data):
#      38     return np.max(np.abs(data))
# ---> 39 calculate_peak(data)
#      40 n = 100
#      41 # A : Normal
#
# <ipython-input-107-dcf249a6ee1d> in calculate_peak(data)
#       4 #1. Peak
#       5 def calculate_peak(data):
# ----> 6     return np.max(data)
#       7
#       8 #2.crest_factor
#
# /usr/local/lib/python3.10/dist-packages/numpy/core/fromnumeric.py in max(a, axis, out, keepdims, initial, where)
#    2808     5
#    2809     """
# -> 2810     return _wrapreduction(a, np.maximum, 'max', axis, None, out,
#    2811                           keepdims=keepdims, initial=initial, where=where)
#    2812
#
# ...

# %% [markdown]
# #Shuffle

# %%
# shuffle
from sklearn.utils import shuffle
dataset = shuffle(data_matrix, random_state=64)

# %% [markdown]
# test/train

# %%
from sklearn.model_selection import train_test_split

X = X_resampled
y = y_resampled

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)
X_train.shape, y_train.shape, X_test.shape, y_test.shape
# Out:
# ((331, 16), (331,), (83, 16), (83,))

# %% [markdown]
# #MinMaxScaler

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
#train
print(scaler.fit(X_train))
print(scaler.data_max_)
# print(scaler.transform(X_train))
#test
print(scaler.fit(X_test))
print(scaler.data_max_)
# print(scaler.transform(X_test))
# Out:
# MinMaxScaler()
# [803.9 432.2  96.9 428.2 100.   67.6  94.7 128.4 134.3  13.5  22.6  72.5
#  275.4 140.3 171.1 133.2]
# MinMaxScaler()
# [798.3 426.9  96.9 428.  100.   67.4  94.4 128.4 134.3  13.5  22.7  72.
#  275.4 140.3 171.1 133.2]

# %%
print(scaler.transform(X_train))
# Out:
# [[0.3988764  0.73935891 0.         ... 0.57142857 0.59090909 0.5       ]
#  [0.04593523 0.98843931 0.83333333 ... 0.         0.45454545 0.5       ]
#  [0.80138797 0.21177089 0.83333333 ... 0.28571429 0.03030303 0.        ]
#  ...
#  [0.66754792 0.41460851 0.         ... 0.71428571 0.74242424 0.625     ]
#  [0.1107072  0.89174987 0.83333333 ... 0.28571429 0.45454545 0.625     ]
#  [0.4494382  0.6941671  0.83333333 ... 0.14285714 0.37878788 0.5       ]]

# %%
(scaler.transform(X_test))
# Out:
# array([[0.39623265, 0.78402522, 0.        , ..., 0.57142857, 0.60606061,
#         0.5       ],
#        [0.50528751, 0.67630058, 0.        , ..., 0.57142857, 0.63636364,
#         0.625     ],
#        [0.65928619, 0.45454545, 0.        , ..., 0.28571429, 0.68181818,
#         0.75      ],
#        ...,
#        [0.49008592, 0.68786127, 0.        , ..., 0.57142857, 0.65151515,
#         0.625     ],
#        [0.3849967 , 0.73042564, 0.83333333, ..., 0.        , 0.37878788,
#         0.5       ],
#        [0.59649703, 0.40830268, 0.83333333, ..., 0.28571429, 0.01515152,
#         0.        ]])

# %%
X_test_minmax = scaler.fit_transform(X_test)
X_train_minmax = scaler.fit_transform(X_train)

X_train_minmax.shape, X_test_minmax.shape, y_train.shape, y_test.shape
# Out:
# ((331, 16), (83, 16), (331,), (83,))

# %% [markdown]
# # Part2

# %%
scaler = MinMaxScaler()
train_data = scaler.fit_transform(X_train)
test_data = scaler.transform(X_test)

# %%
X_test_minmax = scaler.fit_transform(X_test)
X_train_minmax = scaler.fit_transform(X_train)

X_train_minmax.shape, X_test_minmax.shape, y_train.shape, y_test.shape

x_test =X_test_minmax

x_train = X_train_minmax

# %% [markdown]
# ## MLP with 2 hidden layer using Sklearn

# %%
from sklearn.neural_network import MLPClassifier
from sklearn.metrics import confusion_matrix, classification_report
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# Assuming you've trained your model already
model = MLPClassifier(hidden_layer_sizes=(9, 5), activation='relu', solver='adam',
                      batch_size=50, learning_rate_init=0.05,
                       max_iter=100, random_state=64,
                      early_stopping=True, validation_fraction=0.1)
model.fit(x_train, y_train)

# Making predictions on the test set
y_pred = model.predict(x_test)

# Calculating confusion matrix
cf_matrix = confusion_matrix(y_test, y_pred)

# Plotting confusion matrix as a heatmap with fitted text
plt.figure(figsize=(8, 6))
sns.heatmap(cf_matrix, annot=True, fmt='d', cmap='Blues', annot_kws={"size": 12})

# Get the axis to modify layout
plt.gca().set_ylim(len(np.unique(y_test)), 0)  # Fix for matplotlib 3.1.1 and 3.1.2
plt.title('Confusion Matrix')
plt.xlabel('Predicted labels')
plt.ylabel('True labels')

plt.tight_layout()
plt.show()

# Printing classification report
print("Classification Report:")
print(classification_report(y_test, y_pred))
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99        41
#            1       1.00      0.98      0.99        42
#
#     accuracy                           0.99        83
#    macro avg       0.99      0.99      0.99        83
# weighted avg       0.99      0.99      0.99        83

# %% [markdown]
# ### K-Fold Cross Validation

# %%
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_score
kf = KFold(n_splits=10)
scores = cross_val_score(model, X, y, cv=kf)
print(scores)
print("mean Scores:", scores.mean())
print("std Scores:", scores.std())
# Out:
# [0.         0.         0.         0.         0.04878049 0.
#  0.         0.         0.         0.        ]
# mean Scores: 0.004878048780487805
# std Scores: 0.014634146341463417

# %% [markdown]
# ## error

# %%
x_train = np.hstack((np.ones((len(X_train), 1)), X_train))
x_train.shape
# Out:
# (331, 17)

# %%
m = 200
w = np.random.randn(m+1, 1)
print(w.shape)

eta = 0.01
n_epochs = 2000 #N
# Out:
# (201, 1)

# %%
import matplotlib.pyplot as plt
from sklearn.linear_model import Ridge
from sklearn.metrics import PredictionErrorDisplay


ridge = Ridge().fit(X, y)
y_pred = ridge.predict(X)
display = PredictionErrorDisplay(y_true=y, y_pred=y_pred)
display.plot()
plt.show()

# %%
x_test = np.hstack((np.ones((len(X_test), 1)), X_test))
x_test.shape
# Out:
# (83, 17)
